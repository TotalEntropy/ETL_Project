# %%
import pandas as pd
# %autosave 300
# Out:
# Autosaving every 300 seconds

# %%
# Saving csv path, creating pandas df
csv_path = '../Resources/Wikipedia/wiki_movie_plots_deduped.csv'
wiki = pd.read_csv(csv_path)
wiki.head(100)
# Out:
#     Release Year                                              Title  \
# 0           1901                             Kansas Saloon Smashers
# 1           1901                      Love by the Light of the Moon
# 2           1901                            The Martyred Presidents
# 3           1901                   Terrible Teddy, the Grizzly King
# 4           1902                             Jack and the Beanstalk
# 5           1903                                Alice in Wonderland
# 6           1903                            The Great Train Robbery
# 7           1904                                    The Suburbanite
# 8           1905                           The Little Train Robbery
# 9           1905                         The Night Before Christmas
# 10          1906                           Dream of a Rarebit Fiend
# 11          1906  From Leadville to Aspen: A Hold-Up in the Rockies
# 12          1906                                Kathleen Mavourneen
# ...

# %%
wiki['Release Year'].max()
# Out:
# 2017

# %%
# Saving csv path, creating pandas df
csv_path = '../Resources/IMDB/movie_metadata.csv'
imdb = pd.read_csv(csv_path)
imdb.head(100)
# Out:
#     color      director_name  num_critic_for_reviews  duration  \
# 0   Color      James Cameron                   723.0     178.0
# 1   Color     Gore Verbinski                   302.0     169.0
# 2   Color         Sam Mendes                   602.0     148.0
# 3   Color  Christopher Nolan                   813.0     164.0
# 4     NaN        Doug Walker                     NaN       NaN
# 5   Color     Andrew Stanton                   462.0     132.0
# 6   Color          Sam Raimi                   392.0     156.0
# 7   Color       Nathan Greno                   324.0     100.0
# 8   Color        Joss Whedon                   635.0     141.0
# 9   Color        David Yates                   375.0     153.0
# 10  Color        Zack Snyder                   673.0     183.0
# 11  Color       Bryan Singer                   434.0     169.0
# 12  Color       Marc Forster                   403.0     106.0
# 13  Color     Gore Verbinski                   313.0     151.0
# ...

# %%
# Saving csv path, creating pandas df
csv_path = '../Resources/StatCrunch/Box_office_earnings.csv'
Earnings = pd.read_csv(csv_path)
Earnings.head(100)
# Out:
#                                                 Movie Month  Day  Year  \
# 0                                              Avatar   Dec   18  2009
# 1                                             Titanic   Dec   19  1997
# 2                Star Wars Ep. VII: The Force Awakens   Dec   18  2015
# 3                                      Jurassic World   Jun   12  2015
# 4                                        The Avengers   May    4  2012
# 5                                           Furious 7   Apr    3  2015
# 6                             Avengers: Age of Ultron   May    1  2015
# 7       Harry Potter and the Deathly Hallows: Part II   Jul   15  2011
# 8                   Star Wars Ep. VIII: The Last Jedi   Dec   15  2017
# 9                                              Frozen   Nov   22  2013
# 10                               Beauty and the Beast   Mar   17  2017
# 11                            The Fate of the Furious   Apr   14  2017
# ...
